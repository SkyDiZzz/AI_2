# %% [markdown]
# ## Лабораторная работа №2

# %% [markdown]
# ### Работа с библиотеками для визуализации Matplotlib и Seaborn
# ------
# ![image](http://prognear.com/wp-content/uploads/2018/02/スクリーンショット-2018-02-13-20.57.08-300x154.png)

# %% [markdown]
# Установка библиотек:
# + `pip install matplotlib`
# + `pip install seaborn`
#
# Документация:
# + https://matplotlib.org
# + http://seaborn.pydata.org

# %% [markdown]
# Matplotlib поставляется с настройками по умолчанию, которые позволяют настраивать различные свойства. Вы можете управлять значениями по умолчанию почти каждого свойства в matplotlib: размер фигуры, количество точек на дюйм, ширина линии, цвет и стиль осей, свойства оси и сетки, свойств текста и шрифта и так далее. Значения по умолчанию для matplotlib достаточно хороши в большинстве случаев и изменять некоторые свойства нужно только для конкретных случаев.

# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C,S = np.cos(X), np.sin(X)

plt.plot(X,C)
plt.plot(X,S)

plt.show()

# %% [markdown]
# В приведенной ниже ячейке реализованы все параметры фигуры, которые влияют на внешний вид графика. Настройки были явно установлены на значения по умолчанию, но теперь можно в интерактивном режиме играть со значениями, чтобы изучить их влияние.

# %%
# импорт библиотек
import numpy as np
import matplotlib.pyplot as plt

# Создать новую фигуру размером 8x6 точек, используя 100 точек на дюйм
plt.figure(figsize=(8,6), dpi=100)

# Создание нового заголовка
plt.subplot(111)

X = np.linspace(-np.pi, np.pi, 256,endpoint=True)
C,S = np.cos(X), np.sin(X)

# Построение Косинуса синим цветом с непрерывной линией шириной 1 (пиксели)
plt.plot(X, C, color="blue", linewidth=1.0, linestyle="-")

# Синус участка с использованием зеленого цвета с непрерывной линией шириной 1 (пикселей)
plt.plot(X, S, color="green", linewidth=1.0, linestyle="-")

# Установить лимит для X
plt.xlim(-4.0,4.0)

# Установить количество тиков для X
plt.xticks(np.linspace(-4,4,9,endpoint=True))

#Установить лимит для Y
plt.ylim(-1.0,1.0)

# Установить количество тиков для Y
plt.yticks(np.linspace(-1,1,5,endpoint=True))

# Сохранить рисунок с разрешением 72 dpi
# savefig("figure.png",dpi=72)

# Отобразить результат
plt.show()

# %% [markdown]
# Добавим в верхнем левом углу легенду. Для этого требуется только добавления ключевой метки аргумента (которая будет использоваться в поле легенды) к командам графика.

# %%
plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-", label="Косинус")
plt.plot(X, S, color="red",  linewidth=2.5, linestyle="-", label="Синус")

plt.legend(loc='upper left', frameon=False)

# Отобразить результат
plt.show()

# %% [markdown]
# Таким образом, **Matplotlib** позволяет гибко настраивать отображение графиков.
#
# ------

# %% [markdown]
# Еще один бесплатный пакет, основанный на этой библиотеке визуализации данных - это **Seaborn**, которая предоставляет высокоуровневый интерфейс для рисования статистической графики.
#
# Рассмотрим простой пример:

# %% [markdown]
# Когда вы работаете с Seaborn, вы можете либо использовать один из встроенных наборов данных, которые имеются в библиотеке, либо можно загрузить Pandas DataFrame. Чтобы начать работать со встроенным набором данных Seaborn, вы можете использовать функцию load_dataset (), как показано в ячейке нижне. Чтобы получить обзор имеющихся наборов данных перейдите по ссылке https://github.com/mwaskom/seaborn-data.

# %%
# Импортируем необходимые библиотеки
import matplotlib.pyplot as plt
import seaborn as sns

# Загружаем данные
tips = sns.load_dataset("tips")

# Создаем необходимый формат
sns.violinplot(x = "total_bill", data=tips)

# Отображаем
plt.show()

# %% [markdown]
# В большинстве случаев преимущество визуализации данных заключается в том, что работа будет происходить с собственными данными, а не со встроенными наборами данных библиотеки Seaborn. Seaborn лучше всего работает с Pandas DataFrames и массивами, которые содержат целый набор данных.
#
# **Помните**, что DataFrames - это способ хранения данных в прямоугольных сетках, которые легко просматривать. Каждая строка этих сеток соответствует измерениям или значениям экземпляра, в то время как каждый столбец представляет собой вектор, содержащий данные для определенной переменной. Это означает, что строки DataFrame не обязательно должны , но могут содержать значения одного и того же типа: они могут быть числовыми, символьными, логическими и т. Д. DataFrames, как уже известно, поставляются с библиотекой Pandas и определяются как двумерные маркированные структуры данных со столбцами потенциально разных типов.

# %% [markdown]
# ### Тестовый пример
# Рассмотрим на основе набора данных из ресторана о оставленных чаевых
# Имеются следующие признаки:
# * Общий счет (Total bill)
# * Чаевые (Tips)
# * Пол (Sex)
# * Курящий (Smoker)
# * День недели (Day)
# * Время (Time)
# * Количество (Size)

# %%
import pandas as pd
data=pd.read_csv('tips.csv')

# Выводим первые 5 записей набора данных
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Смотрим на количество имеющихся данных
len(data)
# Out:
# 244

# %%
# Реализуем график, что бы посмотреть на взаимосвязь чаевых от общего счета
sns.regplot(x='tip', y='total_bill', data=data, ci=None)
plt.show()

# %%
# Строим гистограмму для общего счета в ресторане
plt.hist(data['total_bill'])
plt.show()

# %%
# Изменим свойства hist
sns.distplot(data['total_bill'], kde=False, rug=True)
plt.show()

# Таким образом получим более наглядую гистограмму

# %%
# Строим boxplot для Общего счета и дня недели
sns.set_style('darkgrid')
sns.boxplot(x='day', y='total_bill', data=data, palette='Blues')
plt.show()

# %%
# Строим boxplot для Пола и оставленных чаевых
sns.boxplot(x='sex', y='tip', data=data, palette='Blues')
plt.show()

# %%
# Добавляем параметры и сохраняем рисунок
fig, ax= plt.subplots()
ax.scatter(data[data['sex']=='Male']['tip'], data[data['sex']=='Male']['total_bill'], color='blue', label='Муж')
ax.scatter(data[data['sex']=='Female']['tip'], data[data['sex']=='Female']['total_bill'], color='green', label='Жен')
ax.set_title('Общий счет и чаевые с распределением по полу', fontdict={'fontsize': 14, 'fontweight': 'bold'})
ax.set_ylabel('Общий счет')
ax.set_xlabel('Чаевые')
ax.legend()
plt.show()

fig.savefig('tips.png', format='png', dpi=250)

# %% [markdown]
# ### Задачи
#
# 1) Проанализируйте и опишите набор данных о ресторане. Построейте графики, которые считаете необходимыми для решения данного задания.
#
# 2) Загрузите файл premier_league.csv. Данный набор данных включает в себя результаты 4560 матчей Премьер-лиги по 380 матчей в каждом из 12 сезонов с 2006/2007 по 2017/2018. Выполните следующие задачи:
# + Опишите имеющиеся признаки;
# + Постройте не менее 8 различных видов графиков;
# + Проанализируйте и опишите набор данных.
#
#
# **Анализ приводить в отдельных ячейках с применением разметки [Markdown](https://sourceforge.net/p/jupiter/wiki/markdown_syntax/)**!

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="ticks", palette="pastel")
data1=pd.read_csv('K:/Semestr6/LabsAI_2/Labs/lb 2/tips.csv')
data2=pd.read_csv('K:/Semestr6/LabsAI_2/Labs/lb 2/premier_league.csv')

# Выводим первые 5 записей набора данных
data1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# #### Задачи для первого задания:
# + 1) Посторить график показывающий общий счет по дням недели
# + 2) Построить график показывающий сколько оставляет чаевых мужчины и женщины по дням недели
# + 3) Построить график показывающий общий счет среди курящих мужчин и женщин

# %%
sns.catplot(x='day',y='total_bill', hue="sex", data=data1,
                height=6, kind="bar", palette="muted")
# Out:
# C:\Users\skydi\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# Из этого графика можно увидеть, что общий счет мужчин всегда больше чем у женщин, а также, что в выходные дни(субота и воскресенье) общий счет посетителей больше чем в буднии дни.

# %%
sns.boxplot(x="day", y="tip",
            hue="sex", palette=["m", "g"],
            data=data1)

# %% [markdown]
# Из этого графика видно, что чаевые чаще всего оставляют мужчины и они склонны отсавлять, в некоторых случаях, больше чаевых чем женщины. Так же мужчины и жензины склонны оставлять больше всего чаевых в диопазоне от 2 до 4.

# %%
sns.catplot(x='sex',y='total_bill', hue="smoker", data=data1,
                height=6, kind="bar", palette="muted")

# %% [markdown]
# Из графика видно, что общий чсет курящих мужчин выше чем у не курящих. В то время как общий счет женщин почти на одном уровне не зависимо курят они или нет.

# %% [markdown]
# # Задачи для второго задания:
# + Опишите имеющиеся признаки;
# + Постройте не менее 8 различных видов графиков;
# + Проанализируйте и опишите набор данных.

# %%
data2.head(50)
# Out:
#             home_team          away_team  home_goals  away_goals result  \
# 0    Sheffield United          Liverpool         1.0         1.0      D
# 1             Arsenal        Aston Villa         1.0         1.0      D
# 2             Everton            Watford         2.0         1.0      H
# 3    Newcastle United     Wigan Athletic         2.0         1.0      H
# 4          Portsmouth   Blackburn Rovers         3.0         0.0      H
# 5             Reading      Middlesbrough         3.0         2.0      H
# 6     West Ham United  Charlton Athletic         3.0         1.0      H
# 7    Bolton Wanderers  Tottenham Hotspur         2.0         0.0      H
# 8   Manchester United             Fulham         5.0         1.0      H
# 9             Chelsea    Manchester City         3.0         0.0      H
# 10            Watford    West Ham United         1.0         1.0      D
# 11  Tottenham Hotspur   Sheffield United         2.0         0.0      H
# 12        Aston Villa            Reading         2.0         1.0      H
# 13    Manchester City         Portsmouth         0.0         0.0      D
# 14   Blackburn Rovers            Everton         1.0         1.0      D
# 15  Charlton Athletic  Manchester United         0.0         3.0      A
# 16             Fulham   Bolton Wanderers         1.0         1.0      D
# 17      Middlesbrough            Chelsea         2.0         1.0      H
# 18          Liverpool    West Ham United         2.0         1.0      H
# 19  Charlton Athletic   Bolton Wanderers         2.0         0.0      H
# 20             Fulham   Sheffield United         1.0         0.0      H
# 21  Tottenham Hotspur            Everton         0.0         2.0      A
# 22            Watford  Manchester United         1.0         2.0      A
# 23     Wigan Athletic            Reading         1.0         0.0      H
# 24    Manchester City            Arsenal         1.0         0.0      H
# 25        Aston Villa   Newcastle United         2.0         0.0      H
# 26   Blackburn Rovers            Chelsea         0.0         2.0      A
# 27      Middlesbrough         Portsmouth         0.0         4.0      A
# 28            Everton          Liverpool         3.0         0.0      H
# 29            Arsenal      Middlesbrough         1.0         1.0      D
# 30   Bolton Wanderers            Watford         1.0         0.0      H
# 31            Chelsea  Charlton Athletic         2.0         1.0      H
# 32   Newcastle United             Fulham         1.0         2.0      A
# 33         Portsmouth     Wigan Athletic         1.0         0.0      H
# 34   Sheffield United   Blackburn Rovers         0.0         0.0      D
# 35  Manchester United  Tottenham Hotspur         1.0         0.0      H
# 36    West Ham United        Aston Villa         1.0         1.0      D
# 37            Reading    Manchester City         1.0         0.0      H
# 38  Charlton Athletic         Portsmouth         0.0         1.0      A
# 39   Bolton Wanderers      Middlesbrough         0.0         0.0      D
# 40            Everton     Wigan Athletic         2.0         2.0      D
# 41   Sheffield United            Reading         1.0         2.0      A
# 42            Watford        Aston Villa         0.0         0.0      D
# 43            Chelsea          Liverpool         1.0         0.0      H
# 44   Blackburn Rovers    Manchester City         4.0         2.0      H
# 45  Tottenham Hotspur             Fulham         0.0         0.0      D
# 46    West Ham United   Newcastle United         0.0         2.0      A
# 47  Manchester United            Arsenal         0.0         1.0      A
# 48          Liverpool   Newcastle United         2.0         0.0      H
# 49          Liverpool  Tottenham Hotspur         3.0         0.0      H
#
#        season
# 0   2006-2007
# 1   2006-2007
# 2   2006-2007
# 3   2006-2007
# 4   2006-2007
# 5   2006-2007
# 6   2006-2007
# 7   2006-2007
# 8   2006-2007
# 9   2006-2007
# 10  2006-2007
# 11  2006-2007
# 12  2006-2007
# 13  2006-2007
# 14  2006-2007
# 15  2006-2007
# 16  2006-2007
# 17  2006-2007
# 18  2006-2007
# 19  2006-2007
# 20  2006-2007
# 21  2006-2007
# 22  2006-2007
# 23  2006-2007
# 24  2006-2007
# 25  2006-2007
# 26  2006-2007
# 27  2006-2007
# 28  2006-2007
# 29  2006-2007
# 30  2006-2007
# 31  2006-2007
# 32  2006-2007
# 33  2006-2007
# 34  2006-2007
# 35  2006-2007
# 36  2006-2007
# 37  2006-2007
# 38  2006-2007
# 39  2006-2007
# 40  2006-2007
# 41  2006-2007
# 42  2006-2007
# 43  2006-2007
# 44  2006-2007
# 45  2006-2007
# 46  2006-2007
# 47  2006-2007
# 48  2006-2007
# 49  2006-2007

# %% [markdown]
# # Описание имеющихся признаков:
#  + home_team - Домашня команда(Хозяева поля)
#  + away_team - Гости(Приехавшая команда)
#  + home_goals - забито голов домашней командой
#  + away_goals - забито голов приехавшей командой
#  + result - результат
#  + season - сезон

# %%
sns.set(style="whitegrid")
f, ax = plt.subplots(figsize=(6, 15))

sns.set_color_codes("pastel")
sns.barplot(x="home_goals", y="home_team", data=data2,
            label="Home goals", color="g")

sns.set_color_codes("muted")
sns.barplot(x="away_goals", y="home_team", data=data2,
            label="Away goals", color="b")

sns.despine(left=True, bottom=True)

# %% [markdown]
# Этот график показывает, соотношение забитых мечей, у каждой команды, за сезон. Из него видно что некоторые команды забили меньше мячей в роли домашних команд, в то время когда они были гостями они забили польще мячей за сезон.

# %%
# Пока не получилось, вернусь к нему потом. График должен был показать сколько и какая команла забила голов.

sns.set(style="ticks", palette="pastel")

#home_teams = data["home_team"]
g = sns.PairGrid(data2.sort_values("home_goals", ascending=False),
                 x_vars=data2.columns[2:-3], y_vars=["home_team"],
                 height=10, aspect=.25)

g.map(sns.stripplot, size=10, orient="h",
      palette="ch:s=1,r=-.1,h=1_r", linewidth=1, edgecolor="w")

g.set(xlim=(0, 10), xlabel="Total", ylabel="")

# Use semantically meaningful titles for the columns
titles = ["Home goals"]

for ax, title in zip(g.axes.flat, titles):

    # Set a different title for each axes
    ax.set(title=title)

    # Make the grid horizontal instead of vertical
    ax.xaxis.grid(False)
    ax.yaxis.grid(True)

sns.despine(left=True, bottom=True)

# %% [markdown]
# Этот график должен был показывать общее количесвто забитых голов у команд, но я напортачил с отображением точки =(
# Хотя в целом он выполняет свою задачу.

# %%
data2['result'].value_counts().plot(kind='bar', rot=0)
plt.title('Результаты')
# Out:
# Text(0.5, 1.0, 'Результаты')

# %% [markdown]
# График показывает результат команд. Ничьих было больше за сезон, в то время как побед добавшних команд было чуть больше чем приезжих.

# %%
sns.set_style('whitegrid')
sns.boxplot(x='home_goals', y='away_goals', data=data2, palette='Blues')
plt.show()

# %% [markdown]
# График типа boxplop, используется для распределения голов.(домашних и приезжих команд)
# Из него видно, что чаще всего команды забивают в диопазоне от 0 до 2 голов.

# %% [markdown]
# Следующие 4-е графика будут показывать результаты 4-ех команд, когда они были гостями. Параметр kind будет изменен для того , чтобы покащать как выглядят похожые данные на разных графиках.

# %%
result = data2[data2['away_team']=='Tottenham Hotspur']
result = result['result'].value_counts().plot(kind='pie', rot=0)
plt.title('Результаты Tottenham Hotspur за все года');

# %%
result = data2[data2['away_team']=='Chelsea']
result = result['result'].value_counts().plot(kind='barh', rot=0)
plt.title('Результаты Chelsea за все года');

# %%
result = data2[data2['away_team']=='Manchester United']
result = result['result'].value_counts().plot(kind='barh', rot=0)
plt.title('Результаты Manchester United за все года');

# %%
result = data2[data2['away_team']=='Southampton']
result = result['result'].value_counts().plot(kind='barh', rot=0)
plt.title('Результаты Southampton за все года');

# %% [markdown]
# Из этих графиков видно, что 3-и из 4-ех команд чаще побеждали принимающую команду, а 4-ая команда чаще проигрывала хозаевам поля. Так же из всех графиков, самыми подходащими являются bar(barh) и pie, так как они для данного случая хорошо показывают соотношения. Хотя из двух этих графиков pie является менее информативным.

# %%
data2['home_team'].value_counts().plot(kind='bar', rot=90, figsize=(20,10))
plt.title('Домашние команды')
# Out:
# Text(0.5, 1.0, 'Домашние команды')

# %% [markdown]
# График показывает столько раз команды были домашние.

# %%
data2['away_team'].value_counts().plot(kind='barh', rot=180, figsize=(20,15))
plt.title('Гости')
# Out:
# Text(0.5, 1.0, 'Гости')

# %% [markdown]
# Этот график аналогичен предыдущему, показывает сколько каждая команда была в роли гостя.

# %%
data2['result'].value_counts().plot(kind='pie', rot='', figsize=(10,10))
plt.title('Результаты за сезон')
# Out:
# Text(0.5, 1.0, 'Результаты за сезон')

# %% [markdown]
# Из этого графикка видно, что чаще матчи заканчивались в пользу доманшних команд, чем в пользу гостей. Так же видно, что результат "Ничья" и "Победа гостей" практически на одном уровне.

# %%
sns.barplot(x=data2['home_goals'], y=data2['away_goals'], palette="rocket")

# %% [markdown]
# Этот график показывает соотношение голов домашних команд к запибым голам команд гостей. Так их графика видно, что на 7 забитых голов, со стороны домашних команд, приходится 1,5 забитых голов со стороны команд гостей.

# %%
plt.figure(figsize=(15,15))
sns.lineplot(x="home_team", y="home_goals", data=data2)

# %% [markdown]
# График показывает, сколько каждая команда забивала голов когда была домашней.
